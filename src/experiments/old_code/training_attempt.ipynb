# %%
# Import required libraries
import json
import pathlib
import numpy as np
import torch
import h5py
from PIL import Image
import matplotlib.pyplot as plt
from typing import Dict, List, Tuple

# ARTIST imports
from artist.scenario.scenario import Scenario
from artist.core.heliostat_ray_tracer import HeliostatRayTracer
from artist.util import config_dictionary, set_logger_config, index_mapping
from artist.util.environment_setup import get_device

# Set up logger
set_logger_config()

# Set device
device = get_device()
print(f"Using device: {device}")
# Out:
# [2025-12-26 11:51:55,549][artist.util.environment_setup][INFO] - No device type provided. The device will default to GPU based on availability and OS, otherwise to CPU.
# [2025-12-26 11:51:55,549][artist.util.environment_setup][WARNING] - Setting device to CPU. ARTIST only supports CPU for MacOS.
# Using device: cpu

# %%
# Define paths to data
DATA_DIR = pathlib.Path("paint_data")
TOWER_FILE = DATA_DIR / "tower-measurements.json"
HELIOSTAT_ID = "AA31"
HELIOSTAT_DIR = DATA_DIR / HELIOSTAT_ID
CALIBRATION_DIR = HELIOSTAT_DIR / "Calibration"
HELIOSTAT_PROPERTIES = HELIOSTAT_DIR / "Properties" / "AA31-heliostat-properties.json"

# Target receiver we're training for
TARGET_NAME = "solar_tower_juelich_lower"

print(f"Data directory: {DATA_DIR}")
print(f"Heliostat: {HELIOSTAT_ID}")
print(f"Target receiver: {TARGET_NAME}")
print(f"Calibration directory: {CALIBRATION_DIR}")
print(f"Heliostat properties: {HELIOSTAT_PROPERTIES}")
# Out:
# Data directory: paint_data
# Heliostat: AA31
# Target receiver: solar_tower_juelich_lower
# Calibration directory: paint_data/AA31/Calibration
# Heliostat properties: paint_data/AA31/Properties/AA31-heliostat-properties.json

# %%
# Load all calibration measurements for AA31 targeting solar_tower_juelich_lower
def load_calibration_measurements(calibration_dir, target_name):
    """
    Load all calibration measurements from the paint_data folder.
    
    Args:
        calibration_dir: Path to Calibration folder containing measurement subfolders
        target_name: Target receiver name to filter by (e.g., 'solar_tower_juelich_lower')
        
    Returns:
        List of dictionaries containing measurement data
    """
    measurements = []
    
    # Iterate through all measurement folders
    measurement_dirs = sorted([d for d in calibration_dir.iterdir() if d.is_dir()])
    
    for measurement_dir in measurement_dirs:
        properties_file = measurement_dir / "properties.json"
        flux_file = measurement_dir / "flux.png"
        
        # Check if both files exist
        if not properties_file.exists() or not flux_file.exists():
            continue
        
        # Load properties
        with open(properties_file) as f:
            props = json.load(f)
        
        # Filter by target name
        if props.get('target_name') != target_name:
            continue
        
        # Load flux image
        flux_img = Image.open(flux_file).convert('L')
        flux_array = np.array(flux_img, dtype=np.float32) / 255.0  # Normalize to [0, 1]
        
        # Store measurement data 
        measurements.append({
            'measurement_id': measurement_dir.name,
            'sun_elevation': props['sun_elevation'],
            'sun_azimuth': props['sun_azimuth'],
            'motor_1': props['motor_position']['axis_1_motor_position'],
            'motor_2': props['motor_position']['axis_2_motor_position'],
            'flux_image': flux_array,
        })
    
    return measurements

# Load all measurements
print(f"Loading calibration measurements from {CALIBRATION_DIR}...")
print(f"Filtering for target: {TARGET_NAME}")

all_measurements = load_calibration_measurements(
    calibration_dir=CALIBRATION_DIR,
    target_name=TARGET_NAME
)

print(f"\nLoaded {len(all_measurements)} measurements targeting {TARGET_NAME}")

# Show statistics
if len(all_measurements) > 0:
    sun_elevations = [m['sun_elevation'] for m in all_measurements]
    sun_azimuths = [m['sun_azimuth'] for m in all_measurements]
    motor_1_values = [m['motor_1'] for m in all_measurements]
    motor_2_values = [m['motor_2'] for m in all_measurements]
    
    print(f"\nDataset statistics:")
    print(f"  Sun elevation: {min(sun_elevations):.1f}° to {max(sun_elevations):.1f}°")
    print(f"  Sun azimuth: {min(sun_azimuths):.1f}° to {max(sun_azimuths):.1f}°")
    print(f"  Motor 1: {min(motor_1_values)} to {max(motor_1_values)} increments")
    print(f"  Motor 2: {min(motor_2_values)} to {max(motor_2_values)} increments")
else:
    print(f"⚠️ No measurements found for target {TARGET_NAME}")

# %%
# Train-test split: 80-20
import random

# Set random seed for reproducibility
random.seed(42)

# Shuffle measurements
shuffled_measurements = all_measurements.copy()
random.shuffle(shuffled_measurements)

# Calculate split index (80% train, 20% test)
split_index = int(len(shuffled_measurements) * 0.8)

train_samples = shuffled_measurements[:split_index]
test_samples = shuffled_measurements[split_index:]

print(f"Dataset split (80-20):")
print(f"  Training samples: {len(train_samples)}")
print(f"  Test samples: {len(test_samples)}")
print(f"  Total: {len(all_measurements)}")

# Show first few measurement IDs from each split
print(f"\nFirst 5 training measurement IDs:")
for sample in train_samples[:5]:
    print(f"  - {sample['measurement_id']} (sun_elev={sample['sun_elevation']:.1f}°, sun_azim={sample['sun_azimuth']:.1f}°)")

print(f"\nFirst 5 test measurement IDs:")
for sample in test_samples[:5]:
    print(f"  - {sample['measurement_id']} (sun_elev={sample['sun_elevation']:.1f}°, sun_azim={sample['sun_azimuth']:.1f}°)")
# Out:
# Dataset split (80-20):
#   Training samples: 42
#   Test samples: 11
#   Total: 53
#
# First 5 training measurement IDs:
#   - 142314 (sun_elev=59.3°, sun_azim=-18.2°)
#   - 162578 (sun_elev=32.7°, sun_azim=-58.4°)
#   - 171007 (sun_elev=30.7°, sun_azim=-24.4°)
#   - 123875 (sun_elev=52.9°, sun_azim=54.2°)
#   - 157267 (sun_elev=41.0°, sun_azim=-58.0°)
#
# First 5 test measurement IDs:
#   - 213875 (sun_elev=60.9°, sun_azim=14.8°)
#   - 244054 (sun_elev=35.1°, sun_azim=50.8°)
#   - 133732 (sun_elev=46.5°, sun_azim=66.8°)
#   - 137978 (sun_elev=46.6°, sun_azim=66.0°)
#   - 147341 (sun_elev=39.7°, sun_azim=-71.1°)

# %% [markdown]
# ## Prepare Dataset for Network
#
# Now we'll prepare the data in the format needed for the neural network:
# - **Inputs:** Sun angles (2) + Heliostat position (3) + Tower position (3) + Target position (3) + Flux image (256x256 flattened) = 65547 features
# - **Outputs:** Motor positions (2)

# %% [markdown]
# ## Make the dataset loadable for the training using torch

# %%
# Create PyTorch Dataset class for single heliostat motor position prediction
from torch.utils.data import Dataset, DataLoader

class HeliostatMotorDataset(Dataset):
    """Dataset for heliostat motor position prediction with flux image as input."""
    
    def __init__(self, samples_list):
        """
        Args:
            samples_list: List of sample dictionaries from load_calibration_measurements()
        """
        self.samples = samples_list
        
        # Compute normalization statistics from the samples
        self._compute_normalization_stats()
        
    def _compute_normalization_stats(self):
        """Compute min/max for normalization."""
        # Sun angles - use reasonable bounds
        self.sun_elev_min, self.sun_elev_max = 0.0, 90.0  # degrees
        self.sun_azim_min, self.sun_azim_max = -180.0, 180.0  # degrees
        
        # Motor positions - compute from data
        all_motor_1 = [s['motor_1'] for s in self.samples]
        all_motor_2 = [s['motor_2'] for s in self.samples]
        self.motor_1_min, self.motor_1_max = min(all_motor_1), max(all_motor_1)
        self.motor_2_min, self.motor_2_max = min(all_motor_2), max(all_motor_2)
        
        print(f"Normalization statistics:")
        print(f"  Sun elevation: [{self.sun_elev_min}, {self.sun_elev_max}]")
        print(f"  Sun azimuth: [{self.sun_azim_min}, {self.sun_azim_max}]")
        print(f"  Motor 1: [{self.motor_1_min}, {self.motor_1_max}]")
        print(f"  Motor 2: [{self.motor_2_min}, {self.motor_2_max}]")
    
    def normalize(self, value, min_val, max_val):
        """Normalize value to [0, 1] range."""
        if max_val - min_val == 0:
            return 0.5
        return (value - min_val) / (max_val - min_val)
    
    def denormalize_motors(self, motor_1_norm, motor_2_norm):
        """Denormalize motor positions from [0, 1] back to increments."""
        motor_1 = motor_1_norm * (self.motor_1_max - self.motor_1_min) + self.motor_1_min
        motor_2 = motor_2_norm * (self.motor_2_max - self.motor_2_min) + self.motor_2_min
        return motor_1, motor_2
    
    def __len__(self):
        return len(self.samples)
    
    def __getitem__(self, idx):
        sample = self.samples[idx]
        
        # Normalize geometric inputs (sun angles only for single heliostat)
        sun_elev_norm = self.normalize(sample['sun_elevation'], self.sun_elev_min, self.sun_elev_max)
        sun_azim_norm = self.normalize(sample['sun_azimuth'], self.sun_azim_min, self.sun_azim_max)
        
        # Geometric features: just sun angles [2 features]
        geometric_features = np.array([sun_elev_norm, sun_azim_norm])
        
        # Flux image: already normalized to [0, 1] during loading
        # Flatten from [256, 256] to [65536]
        flux_flattened = sample['flux_image'].flatten()
        
        # Concatenate geometric features + flattened flux image
        # Total: 2 + 65536 = 65538 features
        full_inputs = np.concatenate([geometric_features, flux_flattened])
        
        # Normalize motor positions (outputs)
        motor_1_norm = self.normalize(sample['motor_1'], self.motor_1_min, self.motor_1_max)
        motor_2_norm = self.normalize(sample['motor_2'], self.motor_2_min, self.motor_2_max)
        outputs = np.array([motor_1_norm, motor_2_norm])
        
        # Convert to PyTorch tensors
        inputs_tensor = torch.tensor(full_inputs, dtype=torch.float32)
        outputs_tensor = torch.tensor(outputs, dtype=torch.float32)
        
        return {
            'inputs': inputs_tensor,           # [65538] = 2 sun angles + 65536 flux pixels
            'motor_positions': outputs_tensor, # [2]
            'metadata': {
                'measurement_id': sample['measurement_id'],
                'sun_elevation': sample['sun_elevation'],
                'sun_azimuth': sample['sun_azimuth'],
            }
        }

print("HeliostatMotorDataset class defined")
# Out:
# HeliostatMotorDataset class defined

# %%
# Create datasets for train and test splits
train_dataset = HeliostatMotorDataset(train_samples)
test_dataset = HeliostatMotorDataset(test_samples)

print(f"\nDataset created:")
print(f"  Training samples: {len(train_dataset)}")
print(f"  Test samples: {len(test_dataset)}")

# Test loading one sample
sample = train_dataset[0]
print(f"\nSample data shapes:")
print(f"  Inputs: {sample['inputs'].shape}")
print(f"  Motor positions: {sample['motor_positions'].shape}")
print(f"\nInput breakdown:")
print(f"  Geometric features (first 11): {sample['inputs'][:11]}")
print(f"  Flux pixels (65536 total, showing first 5): {sample['inputs'][11:16]}")
print(f"  Motor positions (normalized): {sample['motor_positions']}")
# Out:
# Normalization statistics:
#   Sun elevation: [0.0, 90.0]
#   Sun azimuth: [-180.0, 180.0]
#   Motor 1: [20120, 46136]
#   Motor 2: [10428, 60240]
# Normalization statistics:
#   Sun elevation: [0.0, 90.0]
#   Sun azimuth: [-180.0, 180.0]
#   Motor 1: [20852, 41084]
#   Motor 2: [17883, 57915]
#
# Dataset created:
#   Training samples: 42
#   Test samples: 11
#
# Sample data shapes:
#   Inputs: torch.Size([65538])
#   Motor positions: torch.Size([2])
#
# Input breakdown:
#   Geometric features (first 11): tensor([0.6584, 0.4495, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#         0.0000, 0.0000])
#   Flux pixels (65536 total, showing first 5): tensor([0., 0., 0., 0., 0.])
#   Motor positions (normalized): tensor([0.3834, 0.5486])

# %%
# Create DataLoaders
# Note: batch_size=1 since we only have 2 training samples
train_loader = DataLoader(train_dataset, batch_size=1, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=1, shuffle=False)

print("DataLoaders created")
print(f"  Train batches: {len(train_loader)}")
print(f"  Test batches: {len(test_loader)}")

# Test loading a batch
for batch in train_loader:
    print(f"\nBatch shapes:")
    print(f"  Inputs: {batch['inputs'].shape}")  # [batch_size, 65547]
    print(f"  Motor positions: {batch['motor_positions'].shape}")  # [batch_size, 2]
    break
# Out:
# DataLoaders created
#   Train batches: 42
#   Test batches: 11
#
# Batch shapes:
#   Inputs: torch.Size([1, 65538])
#   Motor positions: torch.Size([1, 2])

# %% [markdown]
# ## Define Neural Network
#
# Simple feedforward network for motor position prediction:
# - **Input:** 65,538 features (2 sun angles + 65,536 flux pixels)
# - **Hidden layers:** 256 → 128 → 64 neurons
# - **Output:** 2 motor positions (normalized to [0, 1])
# - **Activation:** ReLU for hidden layers, Sigmoid for output

# %%
import torch.nn as nn

class MotorPositionPredictor(nn.Module):
    """Simple feedforward neural network for motor position prediction."""
    
    def __init__(self, input_dim=65538, hidden_dim1=256, hidden_dim2=128, hidden_dim3=64, output_dim=2):
        super(MotorPositionPredictor, self).__init__()
        
        self.network = nn.Sequential(
            # Input layer → First hidden layer
            nn.Linear(input_dim, hidden_dim1),
            nn.ReLU(),
            
            # First hidden → Second hidden layer
            nn.Linear(hidden_dim1, hidden_dim2),
            nn.ReLU(),
            
            # Second hidden → Third hidden layer
            nn.Linear(hidden_dim2, hidden_dim3),
            nn.ReLU(),
            
            # Third hidden → Output layer
            nn.Linear(hidden_dim3, output_dim),
            nn.Sigmoid()  # Output in [0, 1] for normalized motor positions
        )
    
    def forward(self, x):
        """
        Forward pass through the network.
        
        Args:
            x: Input tensor of shape [batch_size, 65538]
            
        Returns:
            Predicted motor positions of shape [batch_size, 2]
        """
        return self.network(x)

print("MotorPositionPredictor network defined")
# Out:
# MotorPositionPredictor network defined

# %%
# Instantiate the network and move to device
model = MotorPositionPredictor().to(device)

# Print network architecture
print(f"\nNetwork architecture:")
print(model)

# Count total parameters
total_params = sum(p.numel() for p in model.parameters())
trainable_params = sum(p.numel() for p in model.parameters() if p.requires_grad)

print(f"\nTotal parameters: {total_params:,}")
print(f"Trainable parameters: {trainable_params:,}")
# Out:
# Network architecture:
# MotorPositionPredictor(
#   (network): Sequential(
#     (0): Linear(in_features=65538, out_features=256, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=256, out_features=128, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=128, out_features=64, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=64, out_features=2, bias=True)
#     (7): Sigmoid()
#   )
# )
#
# Total parameters: 16,819,266
# Trainable parameters: 16,819,266

# %%
# Test forward pass with one batch
test_batch = next(iter(train_loader))
test_input = test_batch['inputs'].to(device)
test_output = model(test_input)

print(f"\nTest forward pass:")
print(f"  Input shape: {test_input.shape}")
print(f"  Output shape: {test_output.shape}")
print(f"  Output values (normalized motor positions): {test_output.squeeze().detach().cpu().numpy()}")

# Denormalize to get actual motor positions
motor_1_norm, motor_2_norm = test_output.squeeze().detach().cpu().numpy()
motor_1_actual, motor_2_actual = train_dataset.denormalize_motors(motor_1_norm, motor_2_norm)
print(f"  Denormalized motor positions: [{motor_1_actual:.0f}, {motor_2_actual:.0f}] increments")
# Out:
# Test forward pass:
#   Input shape: torch.Size([1, 65538])
#   Output shape: torch.Size([1, 2])
#   Output values (normalized motor positions): [0.46814972 0.5227421 ]
#   Denormalized motor positions: [32299, 36467] increments

# %% [markdown]
# ## Helper Functions for ARTIST Integration
#
# Before training, we need helper functions to:
# 1. Convert sun angles to incident ray directions
# 2. Set up ARTIST scenario and raytracer

# %%
def sun_angles_to_incident_ray_direction(elevation_deg, azimuth_deg):
    """
    Convert sun elevation and azimuth angles to incident ray direction.
    
    Args:
        elevation_deg: Sun elevation angle in degrees (0° = horizon, 90° = zenith)
        azimuth_deg: Sun azimuth angle in degrees (0° = north, 90° = east, 180° = south, -90° = west)
        
    Returns:
        torch.Tensor: Incident ray direction [dx, dy, dz, 0] normalized
    """
    # Convert to radians
    elevation_rad = np.radians(elevation_deg)
    azimuth_rad = np.radians(azimuth_deg)
    
    # Convert spherical to Cartesian coordinates
    # The incident ray direction points FROM the sun TO the heliostat
    # In ENU coordinates:
    # - E (east) is x-axis
    # - N (north) is y-axis
    # - U (up) is z-axis
    
    # Compute direction components
    dx = np.sin(azimuth_rad) * np.cos(elevation_rad)  # East component
    dy = np.cos(azimuth_rad) * np.cos(elevation_rad)  # North component
    dz = -np.sin(elevation_rad)  # Up component (negative because rays come DOWN from sun)
    
    # Create direction vector [dx, dy, dz, 0]
    direction = np.array([dx, dy, dz, 0.0])
    
    # Normalize
    norm = np.sqrt(dx**2 + dy**2 + dz**2)
    direction[:3] = direction[:3] / norm
    
    return torch.tensor(direction, dtype=torch.float32)

# Test the function
test_elevation = 50.56  # degrees
test_azimuth = 59.79    # degrees
test_direction = sun_angles_to_incident_ray_direction(test_elevation, test_azimuth)
print(f"Sun angles: elevation={test_elevation}°, azimuth={test_azimuth}°")
print(f"Incident ray direction: {test_direction.numpy()}")
print(f"Direction magnitude (should be ~1.0): {torch.norm(test_direction[:3]).item():.6f}")
# Out:
# Sun angles: elevation=50.56°, azimuth=59.79°
# Incident ray direction: [ 0.5489919   0.31964922 -0.7722903   0.        ]
# Direction magnitude (should be ~1.0): 1.000000

# %% [markdown]
# ## Dataset Class for PyTorch
#
# Now we'll create a PyTorch Dataset class to handle the calibration measurements.

# %%
# This cell is no longer needed - we're using the pre-generated scenario file

# %%
# This cell is no longer needed - we're using the pre-generated scenario file

# %% [markdown]
# ## Training Configuration and Setup
#
# Define training parameters and set up the optimizer.

# %%
# Training parameters
LEARNING_RATE = 1e-3

# Stage 1: Motor position training (warmup)
STAGE1_EPOCHS = 50
STAGE1_LOG_INTERVAL = 5

# Stage 2: Flux-based fine-tuning
STAGE2_EPOCHS = 100
STAGE2_LOG_INTERVAL = 10

# Create optimizer and loss function
optimizer = torch.optim.Adam(model.parameters(), lr=LEARNING_RATE)
loss_fn = torch.nn.MSELoss()  # MSE loss for both motor positions and flux

print(f"Two-Stage Training Configuration:")
print(f"  Learning rate: {LEARNING_RATE}")
print(f"  Stage 1 (Motor-only warmup): {STAGE1_EPOCHS} epochs")
print(f"  Stage 2 (Flux-based refinement): {STAGE2_EPOCHS} epochs")
print(f"  Total epochs: {STAGE1_EPOCHS + STAGE2_EPOCHS}")
print(f"  Loss function: {loss_fn.__class__.__name__}")
print(f"  Optimizer: {optimizer.__class__.__name__}")
# Out:
# Two-Stage Training Configuration:
#   Learning rate: 0.001
#   Stage 1 (Motor-only warmup): 50 epochs
#   Stage 2 (Flux-based refinement): 100 epochs
#   Total epochs: 150
#   Loss function: MSELoss
#   Optimizer: Adam

# %% [markdown]
# ## Two-Stage Training Loop
#
# **Stage 1: Motor Position Training (Warmup)**
# - Train with motor position loss only (no ARTIST raytracing)
# - Teaches the network the basic sun angle → motor position mapping
# - Fast and stable training
#
# **Stage 2: Flux-Based Fine-Tuning**
# - Add flux-based loss using ARTIST raytracing
# - Refines predictions based on actual flux distributions
# - More physically accurate but slower

# %%
# Load ARTIST scenario for AA31 heliostat
SCENARIO_PATH = pathlib.Path("scenarios/one_heliostat_scenarios/AA31_one_heliostat_scenario.h5")
NUMBER_OF_RAYS = 10

if not SCENARIO_PATH.exists():
    raise FileNotFoundError(f"Scenario file not found: {SCENARIO_PATH}")

print(f"Loading ARTIST scenario from: {SCENARIO_PATH}")

# Load ARTIST scenario
with h5py.File(SCENARIO_PATH, 'r') as scenario_file:
    scenario = Scenario.load_scenario_from_hdf5(
        scenario_file=scenario_file,
        device=device
    )

scenario.set_number_of_rays(number_of_rays=NUMBER_OF_RAYS)

# Get the heliostat group (single heliostat scenario)
heliostat_group = scenario.heliostat_field.heliostat_groups[0]

# Find the target area index for solar_tower_juelich_lower
# Debug: print all attributes to find the right one
print(f"\nDebugging target_areas object:")
print(f"  Type: {type(scenario.target_areas)}")

# Print all non-private attributes and their values
for attr_name in sorted(dir(scenario.target_areas)):
    if not attr_name.startswith('_'):
        try:
            attr_value = getattr(scenario.target_areas, attr_name)
            # Only print if it's data (not methods)
            if not callable(attr_value):
                print(f"  {attr_name}: {attr_value if not isinstance(attr_value, torch.Tensor) else f'<Tensor shape={attr_value.shape}>'}")
        except:
            pass

# The target area keys should be in one of these attributes
# Let's try the most common ones
if hasattr(scenario.target_areas, 'target_area_names'):
    target_area_names = scenario.target_areas.target_area_names
elif hasattr(scenario.target_areas, 'names'):
    target_area_names = scenario.target_areas.names
elif hasattr(scenario.target_areas, 'keys'):
    target_area_names = list(scenario.target_areas.keys)
else:
    # If we can't find it, let's look for any list of strings that has more than just geometry types
    target_area_names = None
    for attr_name in dir(scenario.target_areas):
        if not attr_name.startswith('_') and attr_name != 'geometries':
            try:
                attr_value = getattr(scenario.target_areas, attr_name)
                if isinstance(attr_value, (list, tuple)) and len(attr_value) > 0:
                    if isinstance(attr_value[0], str) and 'tower' in str(attr_value).lower():
                        print(f"\n  >>> Found likely target names in '{attr_name}': {attr_value}")
                        target_area_names = list(attr_value)
                        break
            except:
                pass

if target_area_names is None:
    raise ValueError("Could not find target area names in scenario. Please inspect the output above.")

print(f"\nAvailable target areas in scenario:")
for idx, target_name in enumerate(target_area_names):
    print(f"  [{idx}] {target_name}")

# Get the index for our target
if TARGET_NAME not in target_area_names:
    raise ValueError(f"Target {TARGET_NAME} not found in scenario. Available: {target_area_names}")

target_area_index = target_area_names.index(TARGET_NAME)

print(f"\nScenario loaded successfully:")
print(f"  Number of heliostats: {heliostat_group.number_of_heliostats}")
print(f"  Number of rays: {NUMBER_OF_RAYS}")
print(f"  Target area: {TARGET_NAME} (index {target_area_index})")
print(f"  Device: {device}")
# Out:
# Loading ARTIST scenario from: scenarios/one_heliostat_scenarios/AA31_one_heliostat_scenario.h5
# [2025-12-26 11:51:56,128][artist.scenario.scenario][INFO] - Loading an ARTIST scenario HDF5 file. This scenario file is version 1.0.
# [2025-12-26 11:51:56,129][artist.field.tower_target_areas][INFO] - Loading the tower target areas from an HDF5 file.
# [2025-12-26 11:51:56,130][artist.field.tower_target_areas][WARNING] - No curvature in the east direction set for the multi_focus_tower!
# [2025-12-26 11:51:56,130][artist.field.tower_target_areas][WARNING] - No curvature in the up direction set for the multi_focus_tower!
# [2025-12-26 11:51:56,131][artist.field.tower_target_areas][WARNING] - No curvature in the east direction set for the receiver!
# [2025-12-26 11:51:56,131][artist.field.tower_target_areas][WARNING] - No curvature in the up direction set for the receiver!
# [2025-12-26 11:51:56,131][artist.field.tower_target_areas][WARNING] - No curvature in the east direction set for the solar_tower_juelich_lower!
# [2025-12-26 11:51:56,132][artist.field.tower_target_areas][WARNING] - No curvature in the up direction set for the solar_tower_juelich_lower!
# [2025-12-26 11:51:56,132][artist.field.tower_target_areas][WARNING] - No curvature in the east direction set for the solar_tower_juelich_upper!
# [2025-12-26 11:51:56,132][artist.field.tower_target_areas][WARNING] - No curvature in the up direction set for the solar_tower_juelich_upper!
# [2025-12-26 11:51:56,133][artist.scene.light_source_array][INFO] - Loading a light source array from an HDF5 file.
# [2025-12-26 11:51:56,133][artist.scene.sun][INFO] - Loading sun_1 from an HDF5 file.
# [2025-12-26 11:51:56,134][artist.scene.sun][INFO] - Initializing a sun modeled with a multivariate normal distribution.
# [2025-12-26 11:51:56,137][artist.field.heliostat_field][INFO] - Loading a heliostat field from an HDF5 file.
# [2025-12-26 11:51:56,156][artist.field.heliostat_field][INFO] - Added a heliostat group with kinematic type: rigid_body, and actuator type: linear, to the heliostat field.
#
# Debugging target_areas object:
#   Type: <class 'artist.field.tower_target_areas.TowerTargetAreas'>
#   centers: <Tensor shape=torch.Size([4, 4])>
#   curvatures: <Tensor shape=torch.Size([4, 2])>
#   dimensions: <Tensor shape=torch.Size([4, 2])>
#   geometries: ['planar', 'convex_cylinder', 'planar', 'planar']
#   names: ['multi_focus_tower', 'receiver', 'solar_tower_juelich_lower', 'solar_tower_juelich_upper']
#   normal_vectors: <Tensor shape=torch.Size([4, 4])>
#   number_of_target_areas: 4
#
# Available target areas in scenario:
#   [0] multi_focus_tower
#   [1] receiver
#   [2] solar_tower_juelich_lower
#   [3] solar_tower_juelich_upper
#
# Scenario loaded successfully:
#   Number of heliostats: 1
#   Number of rays: 10
#   Target area: solar_tower_juelich_lower (index 2)
#   Device: cpu

# %%
# Two-stage training implementation
stage1_train_losses = []
stage1_test_losses = []
stage2_train_losses = []
stage2_test_losses = []

print("\n" + "="*80)
print("STAGE 1: MOTOR POSITION TRAINING (WARMUP)")
print("="*80)
print(f"Training for {STAGE1_EPOCHS} epochs with motor position loss only...")
print()

for epoch in range(STAGE1_EPOCHS):
    model.train()
    epoch_loss = 0.0
    num_batches = 0
    
    for batch_idx, batch in enumerate(train_loader):
        optimizer.zero_grad()
        
        # Network forward pass
        inputs = batch['inputs'].to(device)
        ground_truth_motors = batch['motor_positions'].to(device)
        
        predicted_motors_normalized = model(inputs)
        
        # Motor position loss only (no raytracing)
        loss = loss_fn(predicted_motors_normalized, ground_truth_motors)
        
        # Backpropagation
        loss.backward()
        optimizer.step()
        
        epoch_loss += loss.item()
        num_batches += 1
    
    # Average training loss
    avg_train_loss = epoch_loss / num_batches
    stage1_train_losses.append(avg_train_loss)
    
    # Validation
    model.eval()
    test_loss = 0.0
    with torch.no_grad():
        for batch in test_loader:
            inputs = batch['inputs'].to(device)
            ground_truth_motors = batch['motor_positions'].to(device)
            predicted_motors_normalized = model(inputs)
            loss = loss_fn(predicted_motors_normalized, ground_truth_motors)
            test_loss += loss.item()
    
    avg_test_loss = test_loss / len(test_loader)
    stage1_test_losses.append(avg_test_loss)
    
    # Logging
    if epoch % STAGE1_LOG_INTERVAL == 0 or epoch == STAGE1_EPOCHS - 1:
        print(f"Epoch {epoch:3d}/{STAGE1_EPOCHS} | Train Loss: {avg_train_loss:.6f} | Test Loss: {avg_test_loss:.6f}")

print(f"\nStage 1 Complete! Final Loss: {stage1_train_losses[-1]:.6f}")
print(f"Saving Stage 1 checkpoint...")

# Save Stage 1 model
outputs_dir = pathlib.Path("outputs")
outputs_dir.mkdir(exist_ok=True)
stage1_model_path = outputs_dir / "stage1_motor_only_model.pt"
torch.save({
    'epoch': STAGE1_EPOCHS,
    'model_state_dict': model.state_dict(),
    'optimizer_state_dict': optimizer.state_dict(),
    'train_losses': stage1_train_losses,
    'test_losses': stage1_test_losses,
}, stage1_model_path)
print(f"✓ Stage 1 model saved to: {stage1_model_path}")

print("\n" + "="*80)
print("STAGE 2: FLUX-BASED FINE-TUNING")
print("="*80)
print(f"Continuing training for {STAGE2_EPOCHS} epochs with flux-based loss only...")
print(f"Note: Using ONLY flux loss (no motor position regularization)")
print()

for epoch in range(STAGE2_EPOCHS):
    model.train()
    epoch_loss = 0.0
    flux_loss_count = 0
    motor_loss_count = 0
    num_batches = 0
    
    for batch_idx, batch in enumerate(train_loader):
        optimizer.zero_grad()
        
        # Network forward pass
        inputs = batch['inputs'].to(device)
        ground_truth_motors = batch['motor_positions'].to(device)
        
        predicted_motors_normalized = model(inputs)
        
        # Denormalize motor positions for ARTIST raytracing
        motor_1_actual = (
            predicted_motors_normalized[:, 0] * (train_dataset.motor_1_max - train_dataset.motor_1_min) 
            + train_dataset.motor_1_min
        )
        motor_2_actual = (
            predicted_motors_normalized[:, 1] * (train_dataset.motor_2_max - train_dataset.motor_2_min) 
            + train_dataset.motor_2_min
        )
        predicted_motors_actual = torch.stack([motor_1_actual, motor_2_actual], dim=1)
        
        # Get sun angles for this sample
        sample = train_samples[batch_idx]
        incident_ray_direction = sun_angles_to_incident_ray_direction(
            sample['sun_elevation'],
            sample['sun_azimuth']
        ).unsqueeze(0).to(device)
        
        # Activate heliostat and align with predicted positions
        active_heliostats_mask = torch.tensor([1], dtype=torch.int32, device=device)
        
        heliostat_group.activate_heliostats(
            active_heliostats_mask=active_heliostats_mask,
            device=device
        )
        
        heliostat_group.align_surfaces_with_motor_positions(
            motor_positions=predicted_motors_actual,
            active_heliostats_mask=active_heliostats_mask,
            device=device
        )
        
        # Create ray tracer
        ray_tracer = HeliostatRayTracer(
            scenario=scenario,
            heliostat_group=heliostat_group,
            batch_size=1,
            bitmap_resolution=torch.tensor([256, 256], device=device)
        )
        
        target_area_mask = torch.tensor([target_area_index], device=device)
        
        try:
            # Try flux-based loss
            predicted_flux = ray_tracer.trace_rays(
                incident_ray_directions=incident_ray_direction,
                active_heliostats_mask=active_heliostats_mask,
                target_area_mask=target_area_mask,
                device=device
            )
            
            ground_truth_flux = torch.tensor(sample['flux_image'], device=device).unsqueeze(0)
            
            # ONLY flux loss (no motor regularization)
            loss = loss_fn(predicted_flux, ground_truth_flux)
            flux_loss_count += 1
            
        except ValueError as e:
            # Fall back to motor position loss if rays miss target
            print(f"  ⚠ Epoch {epoch}, Sample {batch_idx} ({sample['measurement_id']}): Ray tracing failed - {str(e)}")
            loss = loss_fn(predicted_motors_normalized, ground_truth_motors)
            motor_loss_count += 1
        
        # Backpropagation
        loss.backward()
        optimizer.step()
        
        epoch_loss += loss.item()
        num_batches += 1
    
    # Average training loss
    avg_train_loss = epoch_loss / num_batches
    stage2_train_losses.append(avg_train_loss)
    
    # Validation (using motor loss for speed)
    model.eval()
    test_loss = 0.0
    with torch.no_grad():
        for batch in test_loader:
            inputs = batch['inputs'].to(device)
            ground_truth_motors = batch['motor_positions'].to(device)
            predicted_motors_normalized = model(inputs)
            loss = loss_fn(predicted_motors_normalized, ground_truth_motors)
            test_loss += loss.item()
    
    avg_test_loss = test_loss / len(test_loader)
    stage2_test_losses.append(avg_test_loss)
    
    # Logging
    if epoch % STAGE2_LOG_INTERVAL == 0 or epoch == STAGE2_EPOCHS - 1:
        print(f"Epoch {epoch:3d}/{STAGE2_EPOCHS} | Train Loss: {avg_train_loss:.6f} | Test Loss: {avg_test_loss:.6f} | Flux: {flux_loss_count}/{num_batches} | Motor: {motor_loss_count}/{num_batches}")

print("\n" + "="*80)
print("TRAINING COMPLETE")
print("="*80)
print(f"Stage 1 Final Loss: {stage1_train_losses[-1]:.6f}")
print(f"Stage 2 Final Loss: {stage2_train_losses[-1]:.6f}")
improvement = ((stage1_train_losses[-1] - stage2_train_losses[-1]) / stage1_train_losses[-1] * 100)
if improvement > 0:
    print(f"Improvement: {improvement:.2f}%")
else:
    print(f"Regression: {abs(improvement):.2f}% (Stage 2 made predictions worse)")
# Out:
# ================================================================================
# STAGE 1: MOTOR POSITION TRAINING (WARMUP)
# ================================================================================
# Training for 50 epochs with motor position loss only...
#
# Epoch   0/50 | Train Loss: 0.093876 | Test Loss: 0.113436
# Epoch   5/50 | Train Loss: 0.034556 | Test Loss: 0.047156
# Epoch  10/50 | Train Loss: 0.023806 | Test Loss: 0.045124
# Epoch  15/50 | Train Loss: 0.014613 | Test Loss: 0.068552
# Epoch  20/50 | Train Loss: 0.009124 | Test Loss: 0.051381
# Epoch  25/50 | Train Loss: 0.011909 | Test Loss: 0.036366
# Epoch  30/50 | Train Loss: 0.006085 | Test Loss: 0.031875
# Epoch  35/50 | Train Loss: 0.003669 | Test Loss: 0.052040
# Epoch  40/50 | Train Loss: 0.002986 | Test Loss: 0.043327
# Epoch  45/50 | Train Loss: 0.000891 | Test Loss: 0.049705
# Epoch  49/50 | Train Loss: 0.007700 | Test Loss: 0.080859
#
# Stage 1 Complete! Final Loss: 0.007700
# Saving Stage 1 checkpoint...
# ✓ Stage 1 model saved to: outputs/stage1_motor_only_model.pt
#
# ================================================================================
# STAGE 2: FLUX-BASED FINE-TUNING
# ================================================================================
# Continuing training for 100 epochs with flux-based loss only...
# Note: Using ONLY flux loss (no motor position regularization)
#
#   ⚠ Epoch 0, Sample 17 (180915): Ray tracing failed - No ray intersections on the front of the target area planes.
#   ⚠ Epoch 0, Sample 19 (175655): Ray tracing failed - No ray intersections on the front of the target area planes.
#   ⚠ Epoch 0, Sample 36 (216394): Ray tracing failed - No ray intersections on the front of the target area planes.
#   ⚠ Epoch 0, Sample 39 (177403): Ray tracing failed - No ray intersections on the front of the target area planes.
# Epoch   0/100 | Train Loss: 0.035372 | Test Loss: 0.084087 | Flux: 38/42 | Motor: 4/42
#   ⚠ Epoch 1, Sample 9 (144812): Ray tracing failed - No ray intersections on the front of the target area planes.
#   ⚠ Epoch 1, Sample 17 (180915): Ray tracing failed - No ray intersections on the front of the target area planes.
#   ⚠ Epoch 1, Sample 19 (175655): Ray tracing failed - No ray intersections on the front of the target area planes.
#   ⚠ Epoch 2, Sample 17 (180915): Ray tracing failed - No ray intersections on the front of the target area planes.
#   ⚠ Epoch 2, Sample 19 (175655): Ray tracing failed - No ray intersections on the front of the target area planes.
#   ⚠ Epoch 3, Sample 17 (180915): Ray tracing failed - No ray intersections on the front of the target area planes.
#   ⚠ Epoch 3, Sample 19 (175655): Ray tracing failed - No ray intersections on the front of the target area planes.
#   ⚠ Epoch 4, Sample 19 (175655): Ray tracing failed - No ray intersections on the front of the target area planes.
#   ⚠ Epoch 5, Sample 19 (175655): Ray tracing failed - No ray intersections on the front of the target area planes.
#   ⚠ Epoch 6, Sample 19 (175655): Ray tracing failed - No ray intersections on the front of the target area planes.
#   ⚠ Epoch 7, Sample 19 (175655): Ray tracing failed - No ray intersections on the front of the target area planes.
#   ⚠ Epoch 8, Sample 19 (175655): Ray tracing failed - No ray intersections on the front of the target area planes.
#   ⚠ Epoch 9, Sample 19 (175655): Ray tracing failed - No ray intersections on the front of the target area planes.
#   ⚠ Epoch 10, Sample 19 (175655): Ray tracing failed - No ray intersections on the front of the target area planes.
# Epoch  10/100 | Train Loss: 0.037596 | Test Loss: 0.073451 | Flux: 41/42 | Motor: 1/42
#   ⚠ Epoch 11, Sample 19 (175655): Ray tracing failed - No ray intersections on the front of the target area planes.
#   ⚠ Epoch 12, Sample 19 (175655): Ray tracing failed - No ray intersections on the front of the target area planes.
#   ⚠ Epoch 13, Sample 19 (175655): Ray tracing failed - No ray intersections on the front of the target area planes.
#   ⚠ Epoch 14, Sample 19 (175655): Ray tracing failed - No ray intersections on the front of the target area planes.
#   ⚠ Epoch 15, Sample 19 (175655): Ray tracing failed - No ray intersections on the front of the target area planes.
#   ⚠ Epoch 16, Sample 19 (175655): Ray tracing failed - No ray intersections on the front of the target area planes.
#   ⚠ Epoch 17, Sample 19 (175655): Ray tracing failed - No ray intersections on the front of the target area planes.
#   ⚠ Epoch 18, Sample 19 (175655): Ray tracing failed - No ray intersections on the front of the target area planes.
#   ⚠ Epoch 19, Sample 19 (175655): Ray tracing failed - No ray intersections on the front of the target area planes.
#   ⚠ Epoch 20, Sample 19 (175655): Ray tracing failed - No ray intersections on the front of the target area planes.
# Epoch  20/100 | Train Loss: 0.037570 | Test Loss: 0.067955 | Flux: 41/42 | Motor: 1/42
#   ⚠ Epoch 21, Sample 19 (175655): Ray tracing failed - No ray intersections on the front of the target area planes.
#   ⚠ Epoch 22, Sample 19 (175655): Ray tracing failed - No ray intersections on the front of the target area planes.
#   ⚠ Epoch 23, Sample 19 (175655): Ray tracing failed - No ray intersections on the front of the target area planes.
#   ⚠ Epoch 24, Sample 19 (175655): Ray tracing failed - No ray intersections on the front of the target area planes.
#   ⚠ Epoch 25, Sample 19 (175655): Ray tracing failed - No ray intersections on the front of the target area planes.
#   ⚠ Epoch 26, Sample 19 (175655): Ray tracing failed - No ray intersections on the front of the target area planes.
#   ⚠ Epoch 27, Sample 17 (180915): Ray tracing failed - No ray intersections on the front of the target area planes.
#   ⚠ Epoch 27, Sample 19 (175655): Ray tracing failed - No ray intersections on the front of the target area planes.
#   ⚠ Epoch 28, Sample 19 (175655): Ray tracing failed - No ray intersections on the front of the target area planes.
#   ⚠ Epoch 29, Sample 19 (175655): Ray tracing failed - No ray intersections on the front of the target area planes.
#   ⚠ Epoch 30, Sample 19 (175655): Ray tracing failed - No ray intersections on the front of the target area planes.
# Epoch  30/100 | Train Loss: 0.037578 | Test Loss: 0.068327 | Flux: 41/42 | Motor: 1/42
#   ⚠ Epoch 31, Sample 19 (175655): Ray tracing failed - No ray intersections on the front of the target area planes.
#   ⚠ Epoch 32, Sample 19 (175655): Ray tracing failed - No ray intersections on the front of the target area planes.
#   ⚠ Epoch 33, Sample 19 (175655): Ray tracing failed - No ray intersections on the front of the target area planes.
#   ⚠ Epoch 34, Sample 19 (175655): Ray tracing failed - No ray intersections on the front of the target area planes.
#   ⚠ Epoch 35, Sample 19 (175655): Ray tracing failed - No ray intersections on the front of the target area planes.
#   ⚠ Epoch 36, Sample 19 (175655): Ray tracing failed - No ray intersections on the front of the target area planes.
#   ⚠ Epoch 37, Sample 19 (175655): Ray tracing failed - No ray intersections on the front of the target area planes.
#   ⚠ Epoch 38, Sample 19 (175655): Ray tracing failed - No ray intersections on the front of the target area planes.
#   ⚠ Epoch 39, Sample 19 (175655): Ray tracing failed - No ray intersections on the front of the target area planes.
#   ⚠ Epoch 40, Sample 19 (175655): Ray tracing failed - No ray intersections on the front of the target area planes.
# Epoch  40/100 | Train Loss: 0.037587 | Test Loss: 0.063571 | Flux: 41/42 | Motor: 1/42
#   ⚠ Epoch 41, Sample 19 (175655): Ray tracing failed - No ray intersections on the front of the target area planes.
#   ⚠ Epoch 42, Sample 19 (175655): Ray tracing failed - No ray intersections on the front of the target area planes.
#   ⚠ Epoch 43, Sample 19 (175655): Ray tracing failed - No ray intersections on the front of the target area planes.
#   ⚠ Epoch 44, Sample 19 (175655): Ray tracing failed - No ray intersections on the front of the target area planes.
#   ⚠ Epoch 45, Sample 19 (175655): Ray tracing failed - No ray intersections on the front of the target area planes.
#   ⚠ Epoch 46, Sample 19 (175655): Ray tracing failed - No ray intersections on the front of the target area planes.
#   ⚠ Epoch 47, Sample 19 (175655): Ray tracing failed - No ray intersections on the front of the target area planes.
#   ⚠ Epoch 48, Sample 19 (175655): Ray tracing failed - No ray intersections on the front of the target area planes.
#   ⚠ Epoch 49, Sample 19 (175655): Ray tracing failed - No ray intersections on the front of the target area planes.
#   ⚠ Epoch 50, Sample 19 (175655): Ray tracing failed - No ray intersections on the front of the target area planes.
# Epoch  50/100 | Train Loss: 0.037575 | Test Loss: 0.060671 | Flux: 41/42 | Motor: 1/42
#   ⚠ Epoch 51, Sample 19 (175655): Ray tracing failed - No ray intersections on the front of the target area planes.
#   ⚠ Epoch 52, Sample 19 (175655): Ray tracing failed - No ray intersections on the front of the target area planes.
#   ⚠ Epoch 53, Sample 19 (175655): Ray tracing failed - No ray intersections on the front of the target area planes.
#   ⚠ Epoch 54, Sample 19 (175655): Ray tracing failed - No ray intersections on the front of the target area planes.
#   ⚠ Epoch 55, Sample 19 (175655): Ray tracing failed - No ray intersections on the front of the target area planes.
#   ⚠ Epoch 56, Sample 19 (175655): Ray tracing failed - No ray intersections on the front of the target area planes.
#   ⚠ Epoch 57, Sample 19 (175655): Ray tracing failed - No ray intersections on the front of the target area planes.
#   ⚠ Epoch 58, Sample 19 (175655): Ray tracing failed - No ray intersections on the front of the target area planes.
#   ⚠ Epoch 59, Sample 19 (175655): Ray tracing failed - No ray intersections on the front of the target area planes.
#   ⚠ Epoch 60, Sample 19 (175655): Ray tracing failed - No ray intersections on the front of the target area planes.
# Epoch  60/100 | Train Loss: 0.037574 | Test Loss: 0.054925 | Flux: 41/42 | Motor: 1/42
#   ⚠ Epoch 61, Sample 19 (175655): Ray tracing failed - No ray intersections on the front of the target area planes.
#   ⚠ Epoch 62, Sample 19 (175655): Ray tracing failed - No ray intersections on the front of the target area planes.
#   ⚠ Epoch 63, Sample 19 (175655): Ray tracing failed - No ray intersections on the front of the target area planes.
#   ⚠ Epoch 64, Sample 19 (175655): Ray tracing failed - No ray intersections on the front of the target area planes.
#   ⚠ Epoch 65, Sample 19 (175655): Ray tracing failed - No ray intersections on the front of the target area planes.
#   ⚠ Epoch 66, Sample 19 (175655): Ray tracing failed - No ray intersections on the front of the target area planes.
#   ⚠ Epoch 67, Sample 19 (175655): Ray tracing failed - No ray intersections on the front of the target area planes.
#   ⚠ Epoch 68, Sample 19 (175655): Ray tracing failed - No ray intersections on the front of the target area planes.
#   ⚠ Epoch 69, Sample 19 (175655): Ray tracing failed - No ray intersections on the front of the target area planes.
#   ⚠ Epoch 70, Sample 19 (175655): Ray tracing failed - No ray intersections on the front of the target area planes.
# Epoch  70/100 | Train Loss: 0.037563 | Test Loss: 0.053017 | Flux: 41/42 | Motor: 1/42
#   ⚠ Epoch 71, Sample 19 (175655): Ray tracing failed - No ray intersections on the front of the target area planes.
#   ⚠ Epoch 72, Sample 19 (175655): Ray tracing failed - No ray intersections on the front of the target area planes.
#   ⚠ Epoch 73, Sample 19 (175655): Ray tracing failed - No ray intersections on the front of the target area planes.
#   ⚠ Epoch 74, Sample 19 (175655): Ray tracing failed - No ray intersections on the front of the target area planes.
#   ⚠ Epoch 75, Sample 19 (175655): Ray tracing failed - No ray intersections on the front of the target area planes.
#   ⚠ Epoch 76, Sample 19 (175655): Ray tracing failed - No ray intersections on the front of the target area planes.
#   ⚠ Epoch 77, Sample 19 (175655): Ray tracing failed - No ray intersections on the front of the target area planes.
#   ⚠ Epoch 77, Sample 39 (177403): Ray tracing failed - No ray intersections on the front of the target area planes.
#   ⚠ Epoch 78, Sample 13 (182229): Ray tracing failed - No ray intersections on the front of the target area planes.
#   ⚠ Epoch 78, Sample 19 (175655): Ray tracing failed - No ray intersections on the front of the target area planes.
#   ⚠ Epoch 79, Sample 19 (175655): Ray tracing failed - No ray intersections on the front of the target area planes.
#   ⚠ Epoch 80, Sample 19 (175655): Ray tracing failed - No ray intersections on the front of the target area planes.
# Epoch  80/100 | Train Loss: 0.037661 | Test Loss: 0.101076 | Flux: 41/42 | Motor: 1/42
#   ⚠ Epoch 81, Sample 19 (175655): Ray tracing failed - No ray intersections on the front of the target area planes.
#   ⚠ Epoch 82, Sample 19 (175655): Ray tracing failed - No ray intersections on the front of the target area planes.
#   ⚠ Epoch 83, Sample 19 (175655): Ray tracing failed - No ray intersections on the front of the target area planes.
#   ⚠ Epoch 84, Sample 17 (180915): Ray tracing failed - No ray intersections on the front of the target area planes.
#   ⚠ Epoch 84, Sample 19 (175655): Ray tracing failed - No ray intersections on the front of the target area planes.
#   ⚠ Epoch 84, Sample 23 (152099): Ray tracing failed - No ray intersections on the front of the target area planes.
#   ⚠ Epoch 84, Sample 25 (257820): Ray tracing failed - No ray intersections on the front of the target area planes.
#   ⚠ Epoch 84, Sample 27 (254336): Ray tracing failed - No ray intersections on the front of the target area planes.
#   ⚠ Epoch 85, Sample 17 (180915): Ray tracing failed - No ray intersections on the front of the target area planes.
#   ⚠ Epoch 86, Sample 17 (180915): Ray tracing failed - No ray intersections on the front of the target area planes.
#   ⚠ Epoch 87, Sample 17 (180915): Ray tracing failed - No ray intersections on the front of the target area planes.
#   ⚠ Epoch 88, Sample 6 (148227): Ray tracing failed - No ray intersections on the front of the target area planes.
# Epoch  90/100 | Train Loss: 0.038461 | Test Loss: 0.264538 | Flux: 42/42 | Motor: 0/42
# Epoch  99/100 | Train Loss: 0.038461 | Test Loss: 0.264445 | Flux: 42/42 | Motor: 0/42
#
# ================================================================================
# TRAINING COMPLETE
# ================================================================================
# Stage 1 Final Loss: 0.007700
# Stage 2 Final Loss: 0.038461
# Regression: 399.46% (Stage 2 made predictions worse)

# %% [markdown]
# ## Visualize Training Progress

# %%
# Create outputs directory if it doesn't exist
import pathlib
outputs_dir = pathlib.Path("outputs")
outputs_dir.mkdir(exist_ok=True)

# Plot training and test losses for both stages separately
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 5))

# Stage 1 plot - Motor Position Loss (MSE over 2 values)
ax1.plot(stage1_train_losses, label='Train Loss', marker='o', markersize=2)
ax1.plot(stage1_test_losses, label='Test Loss', marker='s', markersize=2)
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Motor Position Loss (MSE)')
ax1.set_title('Stage 1: Motor Position Training (Warmup)')
ax1.legend()
ax1.grid(True, alpha=0.3)
ax1.set_yscale('log')

# Stage 2 plot - Flux Loss (MSE over 65536 pixels)
ax2.plot(stage2_train_losses, label='Train Loss', marker='o', markersize=2)
ax2.plot(stage2_test_losses, label='Test Loss', marker='s', markersize=2)
ax2.set_xlabel('Epoch')
ax2.set_ylabel('Flux Image Loss (MSE)')
ax2.set_title('Stage 2: Flux-Based Fine-Tuning')
ax2.legend()
ax2.grid(True, alpha=0.3)
ax2.set_yscale('log')

plt.tight_layout()
plt.savefig('outputs/two_stage_training_loss.png', dpi=150, bbox_inches='tight')
plt.show()

print(f"\nStage 1 Results (Motor Position Loss):")
print(f"  Final Train Loss: {stage1_train_losses[-1]:.6f}")
print(f"  Final Test Loss: {stage1_test_losses[-1]:.6f}")

print(f"\nStage 2 Results (Flux Image Loss):")
print(f"  Final Train Loss: {stage2_train_losses[-1]:.6f}")
print(f"  Final Test Loss: {stage2_test_losses[-1]:.6f}")

print(f"\nNote: Stage 1 and Stage 2 losses are not directly comparable.")
print(f"  Stage 1: MSE over 2 normalized motor positions")
print(f"  Stage 2: MSE over 65,536 flux image pixels")

# %% [markdown]
# ## Evaluate Predictions
#
# Let's evaluate the trained model on a test sample and compare predicted vs actual motor positions.

# %%
# Evaluate on test set
model.eval()

test_sample = test_dataset[0]
test_input = test_sample['inputs'].unsqueeze(0).to(device)
ground_truth_motors_norm = test_sample['motor_positions'].cpu().numpy()

# Predict
with torch.no_grad():
    predicted_motors_norm = model(test_input).squeeze().cpu().numpy()

# Denormalize
pred_motor_1, pred_motor_2 = test_dataset.denormalize_motors(
    predicted_motors_norm[0],
    predicted_motors_norm[1]
)

gt_motor_1, gt_motor_2 = test_dataset.denormalize_motors(
    ground_truth_motors_norm[0],
    ground_truth_motors_norm[1]
)

print("="*80)
print("TEST SAMPLE EVALUATION")
print("="*80)
print(f"\nMeasurement ID: {test_sample['metadata']['measurement_id']}")
print(f"Sun elevation: {test_sample['metadata']['sun_elevation']:.2f}°")
print(f"Sun azimuth: {test_sample['metadata']['sun_azimuth']:.2f}°")

print(f"\nGround Truth Motor Positions:")
print(f"  Motor 1: {gt_motor_1:.0f} increments")
print(f"  Motor 2: {gt_motor_2:.0f} increments")

print(f"\nPredicted Motor Positions:")
print(f"  Motor 1: {pred_motor_1:.0f} increments (error: {pred_motor_1 - gt_motor_1:.0f})")
print(f"  Motor 2: {pred_motor_2:.0f} increments (error: {pred_motor_2 - gt_motor_2:.0f})")

print(f"\nAbsolute Errors:")
print(f"  Motor 1: {abs(pred_motor_1 - gt_motor_1):.0f} increments")
print(f"  Motor 2: {abs(pred_motor_2 - gt_motor_2):.0f} increments")

if gt_motor_1 != 0 and gt_motor_2 != 0:
    print(f"\nRelative Errors:")
    print(f"  Motor 1: {abs(pred_motor_1 - gt_motor_1) / abs(gt_motor_1) * 100:.2f}%")
    print(f"  Motor 2: {abs(pred_motor_2 - gt_motor_2) / abs(gt_motor_2) * 100:.2f}%")
# Out:
# ================================================================================
# TEST SAMPLE EVALUATION
# ================================================================================
#
# Measurement ID: 213875
# Sun elevation: 60.90°
# Sun azimuth: 14.80°
#
# Ground Truth Motor Positions:
#   Motor 1: 29486 increments
#   Motor 2: 31300 increments
#
# Predicted Motor Positions:
#   Motor 1: 40888 increments (error: 11402)
#   Motor 2: 47039 increments (error: 15739)
#
# Absolute Errors:
#   Motor 1: 11402 increments
#   Motor 2: 15739 increments
#
# Relative Errors:
#   Motor 1: 38.67%
#   Motor 2: 50.28%

# %% [markdown]
# ## Save the Trained Model

# %%
# Save the final trained model (after both stages)
outputs_dir = pathlib.Path("outputs")
outputs_dir.mkdir(exist_ok=True)

# Save final model checkpoint
final_model_path = outputs_dir / "final_two_stage_model.pt"
torch.save({
    'stage1_epochs': STAGE1_EPOCHS,
    'stage2_epochs': STAGE2_EPOCHS,
    'total_epochs': STAGE1_EPOCHS + STAGE2_EPOCHS,
    'model_state_dict': model.state_dict(),
    'optimizer_state_dict': optimizer.state_dict(),
    'stage1_train_losses': stage1_train_losses,
    'stage1_test_losses': stage1_test_losses,
    'stage2_train_losses': stage2_train_losses,
    'stage2_test_losses': stage2_test_losses,
    'normalization_stats': {
        'motor_1_min': train_dataset.motor_1_min,
        'motor_1_max': train_dataset.motor_1_max,
        'motor_2_min': train_dataset.motor_2_min,
        'motor_2_max': train_dataset.motor_2_max,
    }
}, final_model_path)

print(f"✓ Final model saved to: {final_model_path}")
print(f"  File size: {final_model_path.stat().st_size / 1024 / 1024:.2f} MB")
print(f"\nModel checkpoints saved:")
print(f"  Stage 1 only: {outputs_dir / 'stage1_motor_only_model.pt'}")
print(f"  Final (both stages): {final_model_path}")
# Out:
# ✓ Final model saved to: outputs/final_two_stage_model.pt
#   File size: 192.49 MB
#
# Model checkpoints saved:
#   Stage 1 only: outputs/stage1_motor_only_model.pt
#   Final (both stages): outputs/final_two_stage_model.pt

# %% [markdown]
# ## Summary and Next Steps
#
# **What you've accomplished:**
# 1. ✓ Loaded calibration data from paint_data/AA31/Calibration folder
# 2. ✓ Filtered measurements targeting solar_tower_juelich_lower (53 samples)
# 3. ✓ Implemented 80-20 train-test split
# 4. ✓ Created PyTorch Dataset with sun angles + flux images as inputs
# 5. ✓ Defined a neural network for motor position prediction
# 6. ✓ Implemented training loop with ARTIST flux-based loss
# 7. ✓ Trained the model and evaluated predictions
#
# **Current Training Configuration:**
# - **Dataset:** 53 measurements from AA31 heliostat targeting solar_tower_juelich_lower
# - **Train/Test Split:** 80-20 (~42 training, ~11 test samples)
# - **Input Features:** 2 sun angles + 65,536 flux pixels = 65,538 total
# - **Output:** 2 motor positions (axis 1 and axis 2)
# - **Loss Function:** MSE loss on flux images + motor position regularization
# - **Training Mode:** Flux-based with ARTIST raytracing
#
# **Next steps to improve the pipeline:**
#
# 1. **Increase Dataset Size:**
#    - Add measurements from other targets (solar_tower_juelich_upper, multi_focus_tower)
#    - Add other heliostats from paint_data folder
#    - Generate synthetic training data with data augmentation
#
# 2. **Improve Network Architecture:**
#    - Use convolutional layers to process flux images (currently flattened)
#    - Add separate encoders for sun angles and flux images
#    - Experiment with deeper networks or residual connections
#    - Try attention mechanisms to focus on important flux regions
#
# 3. **Advanced Loss Functions:**
#    - Use ARTIST's KLDivergenceLoss for better distribution matching
#    - Add focal loss to focus on difficult samples
#    - Weighted combination of multiple loss terms
#
# 4. **Training Improvements:**
#    - Increase batch size (currently 1) for more stable gradients
#    - Add learning rate scheduling (e.g., ReduceLROnPlateau)
#    - Implement early stopping to prevent overfitting
#    - Add gradient clipping for training stability
#
# 5. **Hyperparameter Tuning:**
#    - Experiment with different learning rates
#    - Try different network architectures (wider, deeper)
#    - Adjust the weight of motor position regularization
#
# 6. **Validation and Visualization:**
#    - Compare predicted vs ground truth flux images side-by-side
#    - Plot motor position predictions vs ground truth
#    - Analyze errors by sun angle ranges
#    - Visualize learned features in hidden layers
#
# 7. **Multi-Heliostat Generalization:**
#    - Train on multiple heliostats simultaneously
#    - Add heliostat-specific features (position, actuator parameters)
#    - Test transfer learning to new heliostats
